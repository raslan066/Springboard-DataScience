# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
import pandas as pd
df_LG = pd.DataFrame({
    "ordinary": [ 0.39, 0.39, 0.002, 0.72, 0.36 ,0.45 ],
    "Class Weight": [ 0.05, 0.05, 0.001, 0.95, 0.03, 0.95 ],
    "Oversampling": [ 0.03, 0.03, 0.08 ,0.91, 0.01, 0.90 ],
    "SMOTE": [ 0.03, 0.03 ,0.06, 0.93, 0.02 ,0.92 ],
    "ADASYN": [ 0.02, 0.02, 0.08, 0.94, 0.01, 0.97 ],
    "RandomUnderSampler": [ 0.02 ,0.02, 0.08, 0.91, 0.01, 0.90 ],
    "TomekLinks": [ 0.37 ,.37 ,0.001, 0.71, 0.33, 0.42 ],
    "EditedNearestNeighbours": [ 0.37, .37 ,0.001, 0.71, 0.33 ,0.42 ]}, index=['F1 Score','Cohen Kappa','Brier','AUC','Precision','Recall'])
df_LG.drop('Brier', axis=0,inplace=True)

# %% [markdown]
# ## Logistic Regression Performance Metrics

# %%
df_LG.plot(kind="bar",figsize=(12,5),colormap='Greys',rot=0)
plt.title("Performance Metrics",size=24)
# Out:
# Text(0.5, 1.0, 'Performance Metrics')

# %%
df_KN = pd.DataFrame({
    "ordinary": [  0.66, 0.66, 0.006, 0.76 ,0.91, 0.52   ],
    "Class Weight": [   0.70, 0.70, 0.006, 0.79, 0.91, 0.59  ],
    "Oversampling": [  0.59, 0.59, 0.001, 0.84 ,0.51, 0.68  ],
    "SMOTE": [  0.18, 0.18, 0.008, 0.88, 0.10, 0.77  ],
    "ADASYN": [  0.18, 0.17, 0.08, 0.88, 0.10, 0.77   ],
    "RandomUnderSampler": [   0.02, 0.02, 0.09, 0.88, 0.01, 0.85  ],
    "TomekLinks": [   0.66 ,.66, 0.006 ,0.76 ,0.90, 0.52   ],
    "EditedNearestNeighbours": [  0.66, .66 ,0.006, 0.77 ,0.85, 0.53  ]}, index=['F1 Score','Cohen Kappa','Brier','AUC','Precision','Recall'])
df_KN.drop('Brier', axis=0,inplace=True)

# %% [markdown]
# ## KNeighbours  Performance Metrics

# %%
df_LG.plot(kind="bar",figsize=(12,4),colormap='Greys',rot=0)
plt.title("Performance Metrics",size=24)
# Out:
# Text(0.5, 1.0, 'Performance Metrics')

# %%
df_DT = pd.DataFrame({
    "ordinary": [0.83,0.83,0.0004,0.90,0.86,0.80],
    "Class Weight": [0.79,0.79,0.005,0.87,0.83,0.75],
    "Oversampling": [0.79,0.79,0.005,0.87,0.85,0.74],
    "SMOTE": [0.71,0.71,0.009,0.94,0.59,0.89],
    "ADASYN": [0.71,0.71,0.009,0.94,0.59,0.87],
    "RandomUnderSampler": [0.77,0.77,0.005,0.87,0.82,0.73],
    "TomekLinks": [0.79,0.79,0.005,0.87,0.83,0.75],
    "EditedNearestNeighbours": [0.79,0.79,0.005,0.88,0.82,0.75]}, index=['F1 Score','Cohen Kappa','Brier','AUC','Precision','Recall'])
df_DT.drop('Brier', axis=0,inplace=True)

# %% [markdown]
# ## Decision Tree Performance Metrics

# %%
df_LG.plot(kind="bar",figsize=(12,5),colormap='Greys',rot=0)
plt.title("Performance Metrics",size=24)
# Out:
# Text(0.5, 1.0, 'Performance Metrics')

# %%
import pandas as pd
df_RF = pd.DataFrame({
    "ordinary": [ 0.83, 0.83, 0.003, 0.86, 0.98, 0.72  ],
    "Class Weight": [  0.82 ,.82, 0.004, 0.85 ,.98 ,.71 ],
    "Oversampling": [  0.83, 0.83 ,0.003, 0.87, .95, .74 ],
    "SMOTE": [ 0.74 ,0.74, 0.008, 0.93, 0.65 ,0.86 ],
    "ADASYN": [  0.73 ,0.73, 0.008, 0.94, 0.63 ,0.87  ],
    "RandomUnderSampler": [  0.1 ,0.1, 0.02 ,.98 ,0.05, 0.99 ],
    "TomekLinks": [  0.80 ,.80, 0.004, .84, .97 ,.64  ],
    "EditedNearestNeighbours": [  0.82, .82, 0.004, .85 ,.98, .70  ]}, index=['F1 Score','Cohen Kappa','Brier','AUC','Precision','Recall'])
df_RF.drop('Brier', axis=0,inplace=True)

# %% [markdown]
# ## Random Forest Performance Metrics

# %%
df_LG.plot(kind="bar",figsize=(12,5),colormap='Greys',rot=0)
plt.title("Performance Metrics",size=24)
# Out:
# Text(0.5, 1.0, 'Performance Metrics')

# %% [markdown]
# ----

# %% [markdown]
# ## Model Comparison

# %%
df2 = pd.DataFrame()
df2['LogisticRegression'] = df_LG.iloc[0]
df2['KNeighbors'] = df_KN.iloc[0]
df2['RandomForest'] = df_RF.iloc[0]
df2['DecisionTree'] = df_DT.iloc[0]
df2= df2.T
df2.plot(kind="bar",figsize=(12,5),colormap='Greys',rot=0,title="F1 Score")
plt.title("F1 Score",size=24)
# Out:
# Text(0.5, 1.0, 'F1 Score')

# %%
df3 = pd.DataFrame()
df3['LogisticRegression'] = df_LG.iloc[2]
df3['KNeighbors'] = df_KN.iloc[2]
df3['RandomForest'] = df_RF.iloc[2]
df3['DecisionTree'] = df_DT.iloc[2]
df3= df3.T
df3.plot(kind="bar",figsize=(12,5),colormap='Greys',rot=0,title="AUC")
plt.title("AUC",size=24)
# Out:
# Text(0.5, 1.0, 'AUC')

# %%
df_DT

df4 = pd.DataFrame()
df4['LogisticRegression'] = df_LG.iloc[3]
df4['KNeighbors'] = df_KN.iloc[3]
df4['RandomForest'] = df_RF.iloc[3]
df4['DecisionTree'] = df_DT.iloc[3]
df4= df4.T
df4.plot(kind="bar",figsize=(12,5),colormap='Greys',rot=0,title="Precision")
plt.title("Precision",size=24)
# Out:
# Text(0.5, 1.0, 'Precision')

# %%
df_DT

df5 = pd.DataFrame()
df5['LogisticRegression'] = df_LG.iloc[4]
df5['KNeighbors'] = df_KN.iloc[4]
df5['RandomForest'] = df_RF.iloc[4]
df5['DecisionTree'] = df_DT.iloc[4]
df5= df5.T
df5.plot(kind="bar",figsize=(12,5),colormap='Greys',rot=0,title="Recall")
plt.title("Recall",size=24)
# Out:
# Text(0.5, 1.0, 'Recall')

# %%
df_RF
# Out:
#              ordinary  Class Weight  Oversampling  SMOTE  ADASYN  \
# F1 Score         0.83          0.82          0.83   0.74    0.73
# Cohen Kappa      0.83          0.82          0.83   0.74    0.73
# AUC              0.86          0.85          0.87   0.93    0.94
# Precision        0.98          0.98          0.95   0.65    0.63
# Recall           0.72          0.71          0.74   0.86    0.87
#
#              RandomUnderSampler  TomekLinks  EditedNearestNeighbours
# F1 Score                   0.10        0.80                     0.82
# Cohen Kappa                0.10        0.80                     0.82
# AUC                        0.98        0.84                     0.85
# Precision                  0.05        0.97                     0.98
# Recall                     0.99        0.64                     0.70

# %%
import pandas as pd
pd.DataFrame({'tp': [245    ,240    ,251    ,294    ,297    ,335    ,234    ,239],
              'tn': [254161 ,254160 ,254161 ,254007 ,253992 ,247884 ,234159 ,245160],
              'fp': [4      ,5      ,14     ,158    ,173    ,6321   ,6      ,5],
              'fn': [95     ,100    ,89     ,46     ,43     ,5      ,106    ,101],
             'auc': [0.86   ,0.85   ,0.87   ,.93    ,.94    ,.98    ,.84    ,.85]}, 
             index=["ordinary","class_weight","RandomOverSampler","SMOTE","ADASYN","RandomUnderSampler","TomekLinks","EditedNearestNeighbours"])
# Out:
#                           tp      tn    fp   fn   auc
# ordinary                 245  254161     4   95  0.86
# class_weight             240  254160     5  100  0.85
# RandomOverSampler        251  254161    14   89  0.87
# SMOTE                    294  254007   158   46  0.93
# ADASYN                   297  253992   173   43  0.94
# RandomUnderSampler       335  247884  6321    5  0.98
# TomekLinks               234  234159     6  106  0.84
# EditedNearestNeighbours  239  245160     5  101  0.85

# %%
df_p_r= pd.DataFrame(df5.T.iloc[:,2])

# %%
precison = pd.DataFrame(df4.T.iloc[:,2])

# %%
df_p_r['precison']=precison

# %%
df_p_r.columns = ['recall', 'precison']

# %%
df_p_r.sort_values(by='recall')
# Out:
#                          recall  precison
# TomekLinks                 0.64      0.97
# EditedNearestNeighbours    0.70      0.98
# Class Weight               0.71      0.98
# ordinary                   0.72      0.98
# Oversampling               0.74      0.95
# SMOTE                      0.86      0.65
# ADASYN                     0.87      0.63
# RandomUnderSampler         0.99      0.05

# %%
df_p_r.iloc[:,:2].plot(kind="bar",figsize=(12,3),colormap='Greys',rot=45,title="Recall")
plt.title("Recall vs Recall",size=24)
# Out:
# Text(0.5, 1.0, 'Recall vs Recall')

# %%
df_p_r["Recall/Precison"] = df_p_r.recall/df_p_r.precison
df =df_p_r.sort_values(by="Recall/Precison")

# %%
df["Recall/Precison"][:-1].plot(kind="bar",figsize=(12,3),color='k',rot=45,title="Recall")
plt.title("Recall/Precision Ratio",size=24)
# Out:
# Text(0.5, 1.0, 'Recall/Precision Ratio')
